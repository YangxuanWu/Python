# %% [markdown]
# <a href="https://colab.research.google.com/github/YangxuanWu/Python/blob/master/LearningInSummer/new-prepare_country_stats_join_two_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
datapath = os.path.join("datasets", "lifesat")
#将datasets和lifeset这两个路径组合后返回，创建datasets为一级目录，二级目录为lifesat
import urllib
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml2/master/"
os.makedirs(datapath, exist_ok=True)
#讲网络文件导入进datasets
for filename in ("oecd_bli_2015.csv", "gdp_per_capita.csv"):
  url = DOWNLOAD_ROOT + "datasets/lifesat/" + filename
  urllib.request.urlretrieve(url, datapath + filename)
  #将URL表示的网络对象复制到本地文件
  print("Downloading", filename)

# %%
import pandas as pd
oecd_bli = pd.read_csv(datapath + "oecd_bli_2015.csv", thousands=',')
gdp_per_capita = pd.read_csv(datapath + "gdp_per_capita.csv",thousands=',',delimiter='\t',
                             encoding='latin1', na_values="n/a")

# %%
oecd_bli = oecd_bli[oecd_bli["INEQUALITY"]=="TOT"]
oecd_bli
# Out:
#      LOCATION         Country INDICATOR  ...  Value Flag Codes            Flags
# 0         AUS       Australia   HO_BASE  ...   1.10          E  Estimated value
# 1         AUT         Austria   HO_BASE  ...   1.00        NaN              NaN
# 2         BEL         Belgium   HO_BASE  ...   2.00        NaN              NaN
# 3         CAN          Canada   HO_BASE  ...   0.20        NaN              NaN
# 4         CZE  Czech Republic   HO_BASE  ...   0.90        NaN              NaN
# ...       ...             ...       ...  ...    ...        ...              ...
# 3213      EST         Estonia   WL_TNOW  ...  14.90        NaN              NaN
# 3214      ISR          Israel   WL_TNOW  ...  14.48          E  Estimated value
# 3215      RUS          Russia   WL_TNOW  ...  14.97          E  Estimated value
# 3216      SVN        Slovenia   WL_TNOW  ...  14.62        NaN              NaN
# 3217     OECD    OECD - Total   WL_TNOW  ...  14.97        NaN              NaN
#
# ...

# %%
oecd_bli = oecd_bli.pivot(index="Country", columns="Indicator", values="Value")
oecd_bli
# Out:
# Indicator        Air pollution  Assault rate  ...  Water quality  Years in education
# Country                                       ...
# Australia                 13.0           2.1  ...           91.0                19.4
# Austria                   27.0           3.4  ...           94.0                17.0
# Belgium                   21.0           6.6  ...           87.0                18.9
# Brazil                    18.0           7.9  ...           72.0                16.3
# Canada                    15.0           1.3  ...           91.0                17.2
# Chile                     46.0           6.9  ...           73.0                16.5
# Czech Republic            16.0           2.8  ...           85.0                18.1
# Denmark                   15.0           3.9  ...           94.0                19.4
# Estonia                    9.0           5.5  ...           79.0                17.5
# ...

# %%
gdp_per_capita.rename(columns={"2015": "GDP per capita"}, inplace=True)
gdp_per_capita
# Out:
#                                                Country  ... Estimates Start After
# 0                                          Afghanistan  ...                2013.0
# 1                                              Albania  ...                2010.0
# 2                                              Algeria  ...                2014.0
# 3                                               Angola  ...                2014.0
# 4                                  Antigua and Barbuda  ...                2011.0
# ..                                                 ...  ...                   ...
# 185                                            Vietnam  ...                2012.0
# 186                                              Yemen  ...                2008.0
# 187                                             Zambia  ...                2010.0
# 188                                           Zimbabwe  ...                2012.0
# ...

# %%
gdp_per_capita.set_index("Country", inplace=True)
gdp_per_capita
# Out:
#                                                                                    Subject Descriptor  ... Estimates Start After
# Country                                                                                                ...
# Afghanistan                                         Gross domestic product per capita, current prices  ...                2013.0
# Albania                                             Gross domestic product per capita, current prices  ...                2010.0
# Algeria                                             Gross domestic product per capita, current prices  ...                2014.0
# Angola                                              Gross domestic product per capita, current prices  ...                2014.0
# Antigua and Barbuda                                 Gross domestic product per capita, current prices  ...                2011.0
# ...

# %%
full_country_stats = pd.merge(left=oecd_bli, right=gdp_per_capita,left_index=True,right_index=True)
full_country_stats
# Out:
#                  Air pollution  ...  Estimates Start After
# Country                         ...
# Australia                 13.0  ...                 2014.0
# Austria                   27.0  ...                 2015.0
# Belgium                   21.0  ...                 2014.0
# Brazil                    18.0  ...                 2014.0
# Canada                    15.0  ...                 2015.0
# Chile                     46.0  ...                 2014.0
# Czech Republic            16.0  ...                 2015.0
# Denmark                   15.0  ...                 2015.0
# Estonia                    9.0  ...                 2014.0
# Finland                   15.0  ...                 2014.0
# France                    12.0  ...                 2015.0
# Germany                   16.0  ...                 2014.0
# Greece                    27.0  ...                 2014.0
# Hungary                   15.0  ...                 2015.0
# ...

# %%
full_country_stats.sort_values(by="GDP per capita", inplace=True)
full_country_stats
# Out:
#                  Air pollution  ...  Estimates Start After
# Country                         ...
# Brazil                    18.0  ...                 2014.0
# Mexico                    30.0  ...                 2015.0
# Russia                    15.0  ...                 2015.0
# Turkey                    35.0  ...                 2013.0
# Hungary                   15.0  ...                 2015.0
# Poland                    33.0  ...                 2014.0
# Chile                     46.0  ...                 2014.0
# Slovak Republic           13.0  ...                 2015.0
# Czech Republic            16.0  ...                 2015.0
# Estonia                    9.0  ...                 2014.0
# Greece                    27.0  ...                 2014.0
# Portugal                  18.0  ...                 2014.0
# Slovenia                  26.0  ...                 2015.0
# Spain                     24.0  ...                 2014.0
# ...

# %%
remove_indices = [0, 1, 6, 8, 33, 34, 35]
keep_indices = list(set(range(36)) - set(remove_indices))

# %%
full_country_stats[["GDP per capita", 'Life satisfaction']].iloc[keep_indices]
# Out:
#                  GDP per capita  Life satisfaction
# Country
# Russia                 9054.914                6.0
# Turkey                 9437.372                5.6
# Hungary               12239.894                4.9
# Poland                12495.334                5.8
# Slovak Republic       15991.736                6.1
# Estonia               17288.083                5.6
# Greece                18064.288                4.8
# Portugal              19121.592                5.1
# Slovenia              20732.482                5.7
# Spain                 25864.721                6.5
# Korea                 27195.197                5.8
# Italy                 29866.581                6.0
# Japan                 32485.545                5.9
# Israel                35343.336                7.4
# New Zealand           37044.891                7.3
# France                37675.006                6.5
# Belgium               40106.632                6.9
# ...
