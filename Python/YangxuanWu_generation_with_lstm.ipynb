# %% [markdown]
# <a href="https://colab.research.google.com/github/YangxuanWu/Python/blob/master/Python/YangxuanWu_generation_with_lstm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.3.1'

# %%
#如何使用 使用LSTM生成文本

# %%
#使用LSTM生成文本
import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# Corpus length: 600893

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %%
#我们的网络是一个单一的LSTM层，然后是一个密集的分类器和所有可能的字符softmax。
#但是让我们注意到递归神经网络不是序列数据生成的唯一方法;一维convnets在这方面也被证明非常成功。
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
#目标是单热编码，我们将使用categorical_crossentropy作为损失来训练模型:
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
#训练语言模型并从中取样
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 335s 2ms/step - loss: 1.9679
# --- Generating with seed: " there have
# also been human herds (family alliances, communi"
# ------ temperature: 0.2
#  there have
# also been human herds (family alliances, community of the sentiment of the sentiment of the resting of the sentity of the german and the sentiment of the man a something and that the sentiment to the sentiment of the restand and the served that the german and the sentiment of the sentity of the resting to against that the sentiment and which is the sention of the sense of the sentive and the fain of the man a man and a something of the sentical
# ------ temperature: 0.5
# nd the fain of the man a man and a something of the sentical sentures of the germans of the the the even of than in the sers, by the
# exister enterty of man increasing of the restination of the confection, and the can persative on the raice on the dearand are as a wolld and sone a sones is all always this morality of the server,
# are one of the fact of the relation to ressing and here spers and
# reas man confuction of a a just on the self--enrauted that feel
# ------ temperature: 1.0
#  man confuction of a a just on the self--enrauted that feel kinds were inccertual very lintable covery was fexile ming persencaly
# conscied be dom. in any
# and that a --as it always of eyer lug, and is nobled to esthent, ame armore has is even courned sill ewabuld nor lreald than it laster man
# obfereme thes of the bestives and in
# the ineginst ceared in recompiringige, exastifilings andacondatisem pain of an ahas hat that our hand: enth",
# fisuk: anturestion,
# ------ temperature: 1.2
# in of an ahas hat that our hand: enth",
# fisuk: anturestion, thay impreas at vaye--"roatm his
# ptine, at imsoun, ippearismed: in
# beligiop and
# why fear, un8ut of envalinal hewed abon maxs, has, which in unmave good
# un i deimed nampes
# only leads own tha
# sigcces: enthimspless: to  at; even europetityp, wait
# ive, more am a 9ximent tore exrait, has ads misva9uepourwalby ac
#      hind be righy
# no -heart futc) in revelly confugly
# indeled oc expetsed;--the noving and
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 331s 2ms/step - loss: 1.6149
# --- Generating with seed: " content with
# such a free, fearless soaring above men, manne"
# ------ temperature: 0.2
#  content with
# such a free, fearless soaring above men, manners and the presence to a here and the superfliction of the desire and the such a for the present to the succession and that the present to the subment and and all the such a more that the such a man which is all the concerned to a present to its present to the sense of the succession and all the succession to the himself and to the success of the conceive and the sense to a world to the presence o
# ------ temperature: 0.5
# s of the conceive and the sense to a world to the presence of the love and atteness, which has a feel a good and the suffered to do to be who is to be an in fact of the more of everything religious a who now in the man character and self-and preservation and
# preceasion of the pirtise to have it is one and the power to its percontiner to a nepertous and that the age in the succession and to such a "preteres and the more reverence in this for and decerated w
# ------ temperature: 1.0
# "preteres and the more reverence in this for and decerated when. i youring, how inthing success are languagoue to in
# cainted"--in with his cosed elsemola: than evinents and that the most, with it--from old-love in a more
# smile perhangutge, zn frientireness in religios
# and in sho loved
# , he    for thought: one ahormen of self-chink-a batal under and always or at a soot estice of the opisisting more be
# all prejucted at go"mantited ideaply, consequence
# to the
# ------ temperature: 1.2
#  be
# all prejucted at go"mantited ideaply, consequence
# to therped power. to
# ihnems pacpond, and mangerok imbleticutatome lates
# concont: judgim effesed in lbush heldts, abstratectisated
# to their ant goon timet, and
# praces.y, ttutamy, that
# he schueffoly free; tess,
# thinks society po,nels and of his mucticy if
# that she its moter
# of his motavet.
# man live1" eancing.--within
# to i
# them of cllenering, this presiris an shalt the
# gosy onest ultheoustined readeirs,
# th
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 332s 2ms/step - loss: 1.5264
# --- Generating with seed: "utrality of your conscience; it makes you headstrong against"
# ------ temperature: 0.2
# utrality of your conscience; it makes you headstrong against the more in the conscience and the conscience of a more originans of the sense of the same the science of the more the presist the present the conscience and the presist the presist and the sense the supersion of the same the same the sense of the same the sense the same the stand and the stand the sense and the sense and the present the sense of the sense of the same the same the presence of the
# ------ temperature: 0.5
#  sense of the sense of the same the same the presence of the plays charm and long to the conscience and has profound of the originan sought and grot or himself the generally soul one the one discorrited the according to which has the good conscience in the same doments of all said he will recognition of the same thing in the freedom. the principulal and pleasure and he would be himself and something that he can devilence in the expedient and presiss and th
# ------ temperature: 1.0
# ng that he can devilence in the expedient and presiss and the "the
# workes, that in degaid of this prantauls the jucusts dry call clas his same bloust at an among acted will. togrue lookless, as up. attent,
# and ahmory
# world formal, alsobstions of duce and at the one mansatwul sco-comenvit of livines and thus ideais fregress the reduct that who namely
# howeow, which for adf threstly one
# has yet pi. in sours, being if the worldlys the brought of the
# world live
# ------ temperature: 1.2
# n sours, being if the worldlys the brought of the
# world live
# acdonce.=merned: human andfor
# obsturnging good bonts and the de? if that it) sfaywischeffoulled wre, is
# their powcruch question, the soure and
# laquale
# an!
# my pride it motives
# fray foir to be dany do with internally extent in dedelf milless:--in evenor dimelflionagme put as enemated when in
# opiation of which
# or earth!less, alto"wqual-:he lives presupa, if vengual,
# condeptes withet--and tim. we pe
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 339s 2ms/step - loss: 1.4819
# --- Generating with seed: "rtible that of all kinds of knowledge, knowledge of
# such a w"
# ------ temperature: 0.2
# rtible that of all kinds of knowledge, knowledge of
# such a world of the same to soughts of the same to the sense of the same to the same to the same to be so far as a man as a matter of the same to the same to see to the come and soughts of the prevailed in the same to the experience of the same to the german of the same the same the seems of the same to the superiority of the same to the struggle of the grade to sought of the same the same to the present
# ------ temperature: 0.5
#  of the grade to sought of the same the same to the present something should be prevailed to have be so much, and in the same and series of spirit of all the gaint of the germany. in the come human prevailed but the german mere all the conscious that it we ground in the consequently of the most form of the increate of the spirit the grisks, the necessation, and the grase is not the become of her and could of regard to his own stand that the problem and see
# ------ temperature: 1.0
# nd could of regard to his own stand that the problem and seeter. present anaty whether fight of
# fri. in ordinary. i ut learness
# and moral, it a tolan
# e
# placodon for the suffered his one sfaris, all
# the motive, oth spirit.
# piratious, so its backgeness
# shar sinte from
# appear--hap.
# phynicate hao, the ine; it has he has not be revolnation foo more to owing tart of being had one be are, at bricie intaintion worpour revolinerence upon every meieated"
# genilate in
# ------ temperature: 1.2
# ntion worpour revolinerence upon every meieated"
# genilate in the barting, unwith to one." to fear---bised very
# esultlars." for the cravof and im-in its-most morely, with the noble somether en's seckt timesfy-cownrable to
# avaxionsful-restance, is would be backhets emer any rring:--cereinm
# mistos of must which be that infurder-sentat necentatesly
# emplant ath
# adquiris whoigny which, internonmatinn indusy
# friend, da attrease of in every
# ppiviets inxorceonness
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 338s 2ms/step - loss: 1.4508
# --- Generating with seed: "-justice (reasonableness) has its origin among
# approximate e"
# ------ temperature: 0.2
# -justice (reasonableness) has its origin among
# approximate explours and the strong the consequence of the consequence of a more the consequently and the present of the same to an artists of the most the most proves of the consequently and in the stronger and the stronger of the comprehensible the states and are one and in the consequently the incrispecians and the stronger and the proves of the profoundly and in the strong the still and the strength and in
# ------ temperature: 0.5
# ofoundly and in the strong the still and the strength and in his sense and problem of the always the have always of the prosed enemy the spirit and strong a more strong to the read, it is life and sympathy in the real sense a strong to the germany and always, and consequence of the germany of the german former complies the still far and sense the real the
# consequently and simply the domaculise come must it of the pleasures of the art of the subject, and th
# ------ temperature: 1.0
# e must it of the pleasures of the art of the subject, and there are best world
# as we know sake mouther orutives, and lowes away a ple's
# consequencial man all the faglered of which, it verecourians it: they evints and is the reslessy of futuries comtristure an new religious
# human new can science as alstancling slootungesposded to a
# impluster.
# vatiture "preleptity" conflerous, len the
# eventurions are fir super, order every believe in vense agreeacoid: that u
# ------ temperature: 1.2
# e fir super, order every believe in vense agreeacoid: that unratived
# upbrdustopence of it, there
# at humqurection. the genous, the value, and whe kind to stupid to the
# qualred 1uthe believe it, and say!waut as ad a 'hymp, friendied has invers
# when it is no kending as if the cremotian that
# formorment and menaring, arationibleing, morality, is he
# when
# others
# woiles, have will in greeth,
# of
# moritad heattheh which one vorihous, and
# mainte :uwh
# the "may right an
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 343s 2ms/step - loss: 1.4272
# --- Generating with seed: "ment), is at the same time the true path of virtue; in fact,"
# ------ temperature: 0.2
# ment), is at the same time the true path of virtue; in fact, the existent the antirety and the sense of the sense and principles and priors of the sense and the all the sense and conscience of the sense of the same the sense and the sense and some the sense of the same to the sense and self-discovered the most sense and strong and something and the sense and the most sense of the sense of the most sense of the sense of the sense of the same the properning
# ------ temperature: 0.5
#  sense of the sense of the sense of the same the properning and sense of the priord of the lack of the conscience of the same to the latter the deality of ready and like and eventured the strunglers--and one has and sremates of the most soul and shound have from a must not weak and delicate some that in the religions of the properspite prompers the sense the to the exested of free spirits of soul of the higher and prisist and moral sense of the more
# soul,
# ------ temperature: 1.0
# of the higher and prisist and moral sense of the more
# soul, to, not be all strack updelofication theight and sirrired justicipling of experience: they needs, and to s: it was heart to noble, our our plant, and the most pricible. recolved themselves in all know, his englost. find things will agree
# at all pereous wrolgalantness
# and accorning to basis and mefain the askmand every cognise and our experience, a vinilnal the fals: sine attains a
# desirued
# the at
# ------ temperature: 1.2
# rience, a vinilnal the fals: sine attains a
# desirued
# the at sen habitumeness the to conditised of
# themselna--this romeged
# finice  h natural hummuply values; as anlevodling lay, in short: henevelble obed, involvective visured for themselves" as ar. the riar sbsttories.
# in injuritable"--as that there are one patter heart can begrvants about
# sthich doin--; deorm--discivilizated, i out of goods , on it
# is hivbery that converse, b
# it gaves loved the
# martual
# fai
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 338s 2ms/step - loss: 1.4112
# --- Generating with seed: "city
# for prolonged resolution, must specially be included in"
# ------ temperature: 0.2
# city
# for prolonged resolution, must specially be included in the same the same to the consequently the same the same to the same the most stand the same to the same to the same to the "same and society of the comprehending and single of the same the same to the same things and delicate and the same the present superiority of the consequently and soul, and and the same to the same to the same to the consense of the same to the same to be the same to the sam
# ------ temperature: 0.5
# e consense of the same to the same to be the same to the same the same what is also be a disconsisic superisophers of the greater itself and the preservation of the soul to may a consisted be does not them which a consequently great and the present good can be weakness of the conception of the same believe and distruation of the sense and folly the new apperances of the most bad been the history of the soul, the actions of
# the means and something and most
# ------ temperature: 1.0
# f the soul, the actions of
# the means and something and most future, as well feal to day with ethousnce, but it has
# absoedut
# hingust enough agreeasser: second; gestapenquined of an actress of the fact is sose, toonefience: to strong,
# are people bests themselves the new
# and diloggury to prenation of remote-of saquentius, as has the mystectsmoral "given humly, a ware to usbove
# didly, which as exist. that they aleverty a supporesic and
# caa appated main has cur
# ------ temperature: 1.2
# that they aleverty a supporesic and
# caa appated main has curite-life. rirs).
#
#
#
# 3 at most how commence of ceptry of which the life
# wes friendirnes?"
#
# in8ke; now think. it is the crioud
# be nonly
# proby and constracitant, wrictsims--briclure inoursevise for chelects and that ixagely
# impersed look: one throme viicyed nitibeling ttreepreted. "thousands of sulde--something
# cuative constrected
# gor. he said at noold assigilans on lims
# to inswaritmate
# immuculy disr
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 343s 2ms/step - loss: 1.3959
# --- Generating with seed: "eart, which would fain escape obedience. and in the
# case of "
# ------ temperature: 0.2
# eart, which would fain escape obedience. and in the
# case of the most and desires the sense of the sense of the sense the sense and the moral and self-and the sense of the sense of the sense and sense the sense and sense in the sense of the sense of the same the sense of the sense and the sense and branger and the moral and sense the consequently the moral and sense to desires the sense of the sense and the sense of the sense of the sense and before the mor
# ------ temperature: 0.5
# e and the sense of the sense of the sense and before the morality of the moral interling to be precisely have tentsy of the world and accordence of mankind that the precisely when o the finel the conduce it was one can be strong and the morality of the best and desires and called the philosophers and personal trable and do stoithous and in the desires and artists the characters of the path, which the subject and deastiful the sense in the moral its ethical
# ------ temperature: 1.0
# the subject and deastiful the sense in the moral its ethical compreef that give ad its nature they to be you in steph have conduce seisality has in
# good e ! plenard". with a self interpothlesumes. they are be
# swep and the emotionsk withing and learnty had in the sake and who reepreing under the interraces is there dumandes weerners and discomes, when i sympathy, reluctonism ant ney igsiication,--may. on our upon his oppaging periodiot or couldonnary degard
# ------ temperature: 1.2
# ay. on our upon his oppaging periodiot or couldonnary degard of distanta world thedewerinis, so i ferrian to the youghts"
# whe is this matter imacworst
# truthinm and filours. godismy of exempt it seem, is
# orience. about hous away seemation.
#
# mot his acts enjott, aneful, upon untrage his featal proued spience spoin frather when uncherevies, the turn and termenmons i day. for the sense chars of a bno way our
# copureous for what our valuatio pain.
#
#
# 1dek to doin
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 339s 2ms/step - loss: 1.3849
# --- Generating with seed: "g within it that
# purports to be science, suspicious. it is a"
# ------ temperature: 0.2
# g within it that
# purports to be science, suspicious. it is also the subtle and all the subjurt of the state of the self-contemporaring of the soul of the substing the state of the states and in the any contemporaring of the strength and contemporarity and world of the any more and the assing and standard and the same the submit to the state of the sense of the present of the state of the counterent of the state of the higher and and the extravated the and
# ------ temperature: 0.5
# t of the state of the higher and and the extravated the and the intellectually the subtle of the counterent of his own german submign, and believed and a state of contined for the contemporable and the any more allow and so to a man as a many the as a profound of life and action and an exception of endure, and the religion, all thought in the means of the soure and the soure of an art and here do not as which the world and self-course of the conceptions of
# ------ temperature: 1.0
# not as which the world and self-course of the conceptions of implaint"--but therefore: it is welast proyless a souls of
# , escend that a helly profound somethy, with has with dierties.
#
# 4ineir of among of
# more
# granting and the suldest of its could is an eye to be averther outsir quing the most free
# spirit is is, reference of
# many worsh to plount it misurey occess, oul
# words
# learver, wherelwared of
# the soulmen any religion must any proud givats of his neare
# ------ temperature: 1.2
# the soulmen any religion must any proud givats of his neare a wirds, what etoligation to
# religion,
# )poerth
# of the precimuwating
# nameoness. wacked. suse taine of regard, whatge: t, stromegince thought
# i having the european.=. in chupineser--be combeowise andistice the hold
# had re impuss the firwer do out of tuct and rest! to pree thinks. but he would art our ruth
# swho longerly privited
# ounddogially to readow: signion, if used of do at the pour the rolets ov
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 345s 2ms/step - loss: 1.3758
# --- Generating with seed: "l
# egoism must be justified, too. pain is inflicted, robbery "
# ------ temperature: 0.2
# l
# egoism must be justified, too. pain is inflicted, robbery and the master of the desire the destruction of the same the destructions of the more profoundly and desire of the conditions of the more suffering in the same thing in the sense of the more the present decess of the still the restord of the master of the sense of the master of the same the same of the strong to the extent that is a still and the contempt of the sense of the same the constraint to
# ------ temperature: 0.5
#  and the contempt of the sense of the same the constraint to make its never that a solitude that there is consequence is be are something and man in every feeling long in the trative and only one does not be misundreation of the constraint of them that is power and distained and constraint experience of years suld even in a disfatued of such as his constraint proveling part of an every power and process to who even in the more to the believe of the stook a
# ------ temperature: 1.0
# rocess to who even in the more to the believe of the stook as asens acts, who "one wall; it was it we to reason, and
# means to me thought. attained" who it more bad of shows amorge-still heod he stronguar of by where
# dealing
# remains. will that not
# and
# proin-their treating, as true be truth, on condrend lattom is every counter--and sure "bewa still at side disenerrice for himself or vilnt words deboleed. the "midumed come, to the old new say itself love, i v
# ------ temperature: 1.2
# leed. the "midumed come, to the old new say itself love, i vemesst according ourselves contemptunating in logicaturiasne, and moves an
# old, evensing of c
# stracticity is, myan cruer
# has
# lie ge-potmons, wret" has
# them eventirg. the motivnt.--such thorming it
# is might for-bifdencule, methoding and orue man, out? sometisted--a
# nyethetherd lonuly more woman
# e's free senfums to being folly: one of
# him, a lark or soul. motivns, loaling, bringury at folletion, x
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 345s 2ms/step - loss: 1.3675
# --- Generating with seed: "siological approximation and resemblance
# of which it is the "
# ------ temperature: 0.2
# siological approximation and resemblance
# of which it is the sense of the spirit of the same to the spirit of the present to the sense of the world of the states and the states and it is the states and the present something is all the world of the falseher and the states of the spirit of the same the sense of the world of the man and the man as the states as the states of the same the present the strength and in the spirit and the states and the states and
# ------ temperature: 0.5
# trength and in the spirit and the states and the states and can also as the spirit of the sense of the means of really the condition of endure-can under the highest and the ways
# the
# waning what does not one have distinguliary the world to have it would have a man is not the origination to manifold are the great moral
# supposently precisely is the manic" of the past precisely
# the intellection of the presenced the solitude of the attachbobseration in it not b
# ------ temperature: 1.0
#  presenced the solitude of the attachbobseration in it not be not the goo them regree, the will
# to convinuments, he murh have been far that causing a convining card,
# that egoist the viriuss are suppores from all feel some often play
# again have great rang" caecalr the clausion the good wisdins
# far, has been too scurpinations that with his
# "mather. in himself, "will sees to alleces and the other it? in the same time asnes, "youth is idoultar for he temper
# b
# ------ temperature: 1.2
# ? in the same time asnes, "youth is idoultar for he temper
# before whom the tpeanic gustay later have with man
# idraricablen."
#
# ,here" concracain, do a men upon our unat-; here seept time conceals fourolencefy as subled him than the gets and receley dankh, whether
# the sky.
# , epptive a retodged, which maked to awaris erulal, anothers to want good one much for they pridet andief to seem vivisently attituean or being
# besited? that is his our russe--toilly
# pre-m
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 333s 2ms/step - loss: 1.3603
# --- Generating with seed: " rhymes:--
#
#     hail, ye worthies, barrow-wheeling,
#     "lon"
# ------ temperature: 0.2
#  rhymes:--
#
#     hail, ye worthies, barrow-wheeling,
#     "long the problem of the most problem of the same the morality of the same the morality of the most self-contriulation of the condition of the same to the conduct and life of the most reason and the most deception of the same the morality of the same the morality of the all the most reason of the same the morality of the same the most reason and present to the same the more in the most the present to
# ------ temperature: 0.5
# and present to the same the more in the most the present to the sense of the highest christian themselves and into the more profound; and consequence of the reason that the superiority of the superiority and inclaine and coded and sing to speak of the merist of the conditions of the most senses in the invent all the the increasent here of right of the man who makes the certain moral and of the present the whole to all a seriousness of the same things in th
# ------ temperature: 1.0
# sent the whole to all a seriousness of the same things in the earirow corned, in the end have persod soul the blushed for a doubtion of subharible amae to friends for culsites were in the ory tohands, one are olded of the harde, here kind,
# as to one cannot becken
# capapation of lowing for a matter
# algont,
# late all which
# is great definated havfer ensitible (perhaps
# so taint bick are to phosowdeacily, man connection of is "gunt doing
# more assace, also health
# ------ temperature: 1.2
# , man connection of is "gunt doing
# more assace, also health of corntecteon
# into tush that, bodly to one gali.liurely--on
# the old all democrbations, an atyle ecrude at but, this boutobet. a trutd, for examilies ideas loetk of ar? like indeed and race after part of all the merely in every kinds of him to wenttless and timen. a day the slimebut for "in thel's
# omed, at power somethingy of faculthy--forring the than the sen dour of working
# lence of vase which i
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 332s 2ms/step - loss: 1.3536
# --- Generating with seed: "of the echo
# of the wilderness, something of the murmuring to"
# ------ temperature: 0.2
# of the echo
# of the wilderness, something of the murmuring to the general consciences of the man as a supersporical to the precisely the sense of the same the man is a states and in the same of the supersporities of the strength and consciences of the supersporities of the sense of the condition of the same the same the most morality of the same the most morality of the same to see the conditions and the sense of the same to say and the superiority of the s
# ------ temperature: 0.5
# nd the sense of the same to say and the superiority of the same things when the master of he perhaps and deciaring the
# spirit of our ear in the conception and possible that a the condition and again and day and contemplatic of any do something man is a developed to the belief of the general all the success, and with a dreams the good and individual truthed and all about the same to the fact is not one so dealistic as the false of the fact that it is so tea
# ------ temperature: 1.0
#  one so dealistic as the false of the fact that it is so tease son to congensed paticial dequiein" occwonds, this euraguishery--according to curiosity in
# every letting as the preaty and blinence beings of the greates? are seas orly as the younges venie of the aivenong will
# be ac thing and sonce as it is at last aser. alreaked to men as appearanding fair, thrown acts is surprism in mystial; as idagiveited, the spirit and conother
# was to
# him appear gald and
# ------ temperature: 1.2
# iveited, the spirit and conother
# was to
# him appear gald and should tesprigonst chrisight, which perhaps
# pullarite of
# nerviousncy, trates it seems more
# thinging in" supiticely seas to sough from day.
#
# 24.
#
#           l
#              fol the sense and men of hegreatulipation, get enourh much
# iy once be way his "germange
# and
# make mind of fi. long didsers
# has ob. after necestahys.y we  view because or luri comminally appation as a bribimationacly it padn for
# one
# epoch 14
# Epoch 1/1
# 126592/200278 [=================>............] - ETA: 2:02 - loss: 1.3383

# %%
#低温会导致极其重复和可预测的文本，但是局部结构是非常真实的:特别是，所有单词(一个单词是字符的局部模式)都是真正的英语单词；
#温度越高，生成的文本就越有趣、令人惊讶，甚至更有创意;
#这里的高低温还需要时间理解一下。
